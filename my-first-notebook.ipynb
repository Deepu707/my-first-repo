# %%
The difference between hardware and software is straightforward:

Hardware: The physical components of a computer system that you can touch and see.
Example: A keyboard or CPU.

Software: The set of instructions, programs, or applications that tell the hardware what to do. It’s intangible and runs on hardware.
Example: Microsoft Word or Google Chrome.
